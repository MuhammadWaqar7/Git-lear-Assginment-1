# %% [markdown]
# ### Data is new Oil
# - 281 TB of data is used in training OpenAI GPT-5
# - flex jobs

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\musheer khan\anaconda5\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\musheer khan\anaconda5\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
import requests # for http methods link,get,post
from bs4 import BeautifulSoup # for webscapting methods

# %%
url ="https://m.timesjobs.com/mobile/jobs-search-result.html?txtKeywords=cloud+data+engineers&cboWorkExp1=-1&txtLocation="

# %%
web=requests.get(url).content

# %%
web
# Out:
# b'\n\n\n\n\n\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en" class="no-js">\n<head>\n\t<meta name="viewport" content="width=device-width, initial-scale=1"/>\n\t<meta name="theme-color" content="#E72828">\n\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t<title>165806 Cloud Data Engineers Jobs in India | Cloud Data Engineers Job | Jobs in Cloud Data Engineers | TimesJobs</title>\n\t\t\t\t\t\t<meta property="og:title" content="165806 Cloud Data Engineers Jobs in India | Cloud Data Engineers Job | Jobs in Cloud Data Engineers | TimesJobs">\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\t\n\t\n\t    \n\n\t\n\t    <meta name="description" content="Explore 165806 Cloud Data Engineers Jobs in Delhi NCR, Mumbai, Bangalore, Hyderabad, Chennai, Kolkata, Pune and Ahmedabad on TimesJobs. Find top opportunities inCloud Data Engineersand more. Register to apply for Jobs,  Work from Home Jobs , Freshers Jobs ,  Part time jobs and  Experienced positions inCloud Data Engineers" />\n\t    <meta property="og:description" content="Explore 165806 Cloud Data Engineers Jobs in Delhi NCR, Mumbai, Bangalore, Hyderabad, Chennai, Kolkata, Pune and Ahmedabad on TimesJobs. Find top opportunities inCloud Data Engineersand more. Register to apply for Jobs,  Work from Home Jobs , Freshers Jobs ,  Part time jobs and  Experienced positions inCloud Data Engineers">\n\t     \n\t\n\t\n\n\n\t\n\t\t<meta name="keywords" content="165806 Cloud Data Engineers jobs, jobs in Cloud Data Engineers, jobs for Cloud Data Engineers, job opportunities for Cloud Data Engineers, Cloud Data Engineers jobs in india, search jobs for Cloud Data Engineers, employment opportunities in Cloud Data Engineers" />\n\t\n\t\n\n<meta name="verify-v1" content="IhxUOh7zUxPrSR+zxDq78yJF7B/onzfTK5jhpD2s2dQ=" />\n<meta name="Owner" content="Timesjobs.com" />\n<meta name="Copyright" content="2025 Timesjobs.com" />\n<meta name="Author" content="Timesjobs.com" />\n<meta name="classification" content="India Jobs and Career: Post Jobs, Search Resumes, Resume Development, online jobs" />\n<meta name="distribution" content="global" />\n<meta name="rating" content="General" />\n<meta name="subject" content="India jobs, job search, career portal, TimesJobs" />\n<meta name="page-type" content="Job Portal  India" />\n<meta name="audience" content="all" />\n<meta name="robots" content="index, follow" />\n<meta name="language" content="English" />\n<meta http-equiv="content-type" content="text/html; charset=UTF8" />\n\n\n\n\n\n\n\n\n\n\n\n\n\n<link rel="preconnect" href="https://fonts.googleapis.com">\n<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>\n<link href="https://fonts.googleapis.com/css2?family=Nunito+Sans:ital,opsz,wght@0,6..12,200..1000;1,6..12,200..1000&display=swap" rel="stylesheet">\n<link rel="stylesheet" href="/resources/css/jquery.mobile-1.4.5.css?v=1.1.3" />\n<link rel="stylesheet" href="/resources/css/tj-wap-theme.css?v=1.1.3" />\n<link rel="stylesheet" href="/resources/css/wap-global.css?v=1.1.3" />\n<!-- <link rel="stylesheet" href="/resources/css/wap-global.css" /> -->\n<!-- <link href="https://plus.google.com/+timesjobs" rel="publisher" /> -->\n<script type="text/javascript" src="/resources/js/jquery-2.1.4.min.js"></script>\n<script type="text/javascript" src="/resources/js/tjwap.js?v=1.1.1"></script>\n<script type="text/javascript" src="/resources/js/jquery.mobile-1.4.5.js"></script>\n<script type="text/javascript" src="/resources/js/multiselect-shorter.js"></script>\n<script type="text/javascript" src="/resources/js/profilepreview.js?v=1.1.1"></script>\n<script type="text/javascript" src="/resources/js/engine.js"></script>\n<script type="text/javascript" src="/resources/js/util.js"></script>\n<script type="text/javascript" src="/resources/js/ajaxController.js"></script>\n        \n        \n        \n        \n\t\n\t\t\n\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\t<link  ...

# %%
soup=BeautifulSoup(web,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
# <head>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="#E72828" name="theme-color"/>
# <title>165806 Cloud Data Engineers Jobs in India | Cloud Data Engineers Job | Jobs in Cloud Data Engineers | TimesJobs</title>
# <meta content="165806 Cloud Data Engineers Jobs in India | Cloud Data Engineers Job | Jobs in Cloud Data Engineers | TimesJobs" property="og:title"/>
# <meta content="Explore 165806 Cloud Data Engineers Jobs in Delhi NCR, Mumbai, Bangalore, Hyderabad, Chennai, Kolkata, Pune and Ahmedabad on TimesJobs. Find top opportunities inCloud Data Engineersand more. Register to apply for Jobs,  Work from Home Jobs , Freshers Jobs ,  Part time jobs and  Experienced positions inCloud Data Engineers" name="description"/>
# <meta content="Explore 165806 Cloud Data Engineers Jobs in Delhi NCR, Mumbai, Bangalore, Hyderabad, Chennai, Kolkata, Pune and Ahmedabad on TimesJobs. Find top opportunities inCloud Data Engineersand more. Register to apply for Jobs,  Work from Home Jobs , Freshers Jobs ,  Part time jobs and  Experienced positions inCloud Data Engineers" property="og:description"/>
# <meta content="165806 Cloud Data Engineers jobs, jobs in Cloud Data Engineers, jobs for Cloud Data Engineers, job opportunities for Cloud Data Engineers, Cloud Data Engineers jobs in india, search jobs for Cloud Data Engineers, employment opportunities in Cloud Data Engineers" name="keywords"/>
# <meta content="IhxUOh7zUxPrSR+zxDq78yJF7B/onzfTK5jhpD2s2dQ=" name="verify-v1"/>
# <meta content="Timesjobs.com" name="Owner"/>
# <meta content="2025 Timesjobs.com" name="Copyright"/>
# <meta content="Timesjobs.com" name="Author"/>
# <meta content="India Jobs and Career: Post Jobs, Search Resumes, Resume Development, online jobs" name="classification"/>
# <meta content="global" name="distribution"/>
# <meta content="General" name="rating"/>
# <meta content="India jobs, job search, career portal, TimesJobs" name="subject"/>
# <meta content="Job Portal  India" name="page-type"/>
# <meta content="all" name="audience"/>
# <meta content="index, follow" name="robots"/>
# <meta content="English" name="language"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Nunito+Sans:ital,opsz,wght@0,6..12,200..1000;1,6..12,200..1000&amp;display=swap" rel="stylesheet"/>
# <link href="/resources/css/jquery.mobile-1.4.5.css?v=1.1.3" rel="stylesheet"/>
# <link href="/resources/css/tj-wap-theme.css?v=1.1.3" rel="stylesheet"/>
# <link href="/resources/css/wap-global.css?v=1.1.3" rel="stylesheet"/>
# <!-- <link rel="stylesheet" href="/resources/css/wap-global.css" /> -->
# <!-- <link href="https://plus.google.com/+timesjobs" rel="publisher" /> -->
# <script src="/resources/js/jquery-2.1.4.min.js" type="text/javascript"></script>
# <script src="/resources/js/tjwap.js?v=1.1.1" type="text/javascript"></script>
# <script src="/resources/js/jquery.mobile-1.4.5.js" type="text/javascript"></script>
# <script src="/resources/js/multiselect-shorter.js" type="text/javascript"></script>
# <script src="/resources/js/profilepreview.js?v=1.1.1" type="text/javascript"></script>
# <script src="/resources/js/engine.js" type="text/javascript"></script>
# <script src="/resources/js/util.js" type="text/javascript"></script>
# <script src="/resources/js/ajaxController.js" type="text/javascript"></script>
# <link href="https://m.timesjobs.com/mobile/jobs-search-result.html" rel="canonical"/>
# <link href="https://www.timesjobs.com/candidate/job-search.html" media="only screen and (max-width: 640px)" rel="alternate"/>
# <script type="application/ld+json">
#     {
# 	"@context": "https://schema.org",
# 	"@type": "Organization",
# 	"location": {
# 		"@type": "Place",
# 		"address": "TimesJobs.com, Times Business Solutions (A Division of Times Internet Ltd.), Times Center (Digital Content Production Facility), FC - 6, (Ground Floor), Sector 16 A, Film City, NOIDA - 201 301, Uttar Pradesh, India"
# 	},
# 	"name": "TimesJobs.com",
# 	"description": "TimesJobs: India's Leading Job Portal",
# 	"logo": "https://static.timesjobs.com/images_cand/tj_images/personlisation/tj-logo-new.png",
# 	"url": "https://www.timesjobs.com",
# 	"email": "timesjobs@timesgroup.com"
# 	}
# </script>
# <!-- <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-6237678872163755"
#      crossorigin="anonymous"></script> -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-KP94FPN3');</script>
# <!-- End Google Tag Manager -->
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KP94FPN3" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- <marquee style="background: #FEB95F; padding: 5px 0; font-size:14px; position: fixed; z-index: 10000; top: 0; width: 100%;"> <strong>Service alert:</strong> TimesJobs will be down for maintenance from <strong>Nov 30th, 6:00 PM to Dec 1st, 11:00 AM </strong></marquee>
# 	<style>
# 		.ui-page{padding-top: 28px !important;}
# 		.srp-main-page{padding-top: 144px !important;}
# 		.srp-main-page .ui-header-fixed{top: 28px !important;}
# 	</style> -->
# <script src="/resources/js/engine.js" type="text/javascript"></script>
# <script src="/resources/js/util.js" type="text/javascript"></script>
# <script src="/resources/js/ajaxController.js" type="text/javascript"></script>
# <!-- <script async='async' src='https://www.googletagservices.com/tag/js/gpt.js'></script> -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
# 	googletag.defineSlot('/22683326305/tjdetailpage_m', [300, 250], 'gpt-passback').addService(googletag.pubads());
# 	googletag.defineSlot('/22683326305/tj_300x250_inventory', [300, 250], 'div-gpt-ad-1730193280415-0').addService(googletag.pubads());
#     googletag.defineSlot('/22683326305/tj_300x250_inventory_2', [300, 250], 'div-gpt-ad-1730193110443-0').addService(googletag.pubads());
# 	googletag.defineSlot('/22683326305/tj_300x250_inventory_3', [300, 250], 'div-gpt-ad-1730193223085-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <script type="text/javascript">
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   var queryList="&txtKeywords=cloud+data+engineers";
# </script>
# <div class="srp-main-page" data-role="page">
# <div class="srp-main-header" data-position="fixed" data-role="header">
# <a class="back-btn" data-icon="menuback" data-iconpos="notext" data-rel="back" href="#">Back</a>
# <a class="top-search-srp" data-role="none" href="/mobile/jobs-search.html"><span>cloud data engineers</span></a>
# <div class="clearfix"></div>
# <h1 class="ui-title-seo" id="totalJobsCount">165806
#
#
#
#         Jobs found
#
#
# </h1>
# <!-- <a href="#" class="srp-create-job-alert">Create job alert</a> -->
# </div>
# <!-- <div data-role="header" data-position="fixed" class="main-header filter-header">
# <a href="#" data-icon="menuback" data-iconpos="notext" class="back-btn filter-back" onclick="enableGetMoreJobs()">Back</a>
# <div><h2 class="ui-title-seo">Filter by</h2></div>
# </div> -->
# <div class="guest-srch" id="srpDiv" role="main">
# <div id="shortListLoader"></div>
# <div role="main">
# <ul class="ui-content search-result" id="jobsListULid">
# <li>
# <div class="srp-listing clearfix" id="liDiv70262323">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/b-e-b-tech-diploma-engineers-new-global-technologies-bengaluru-bangalore-chennai-hyderabad-secunderabad-kolkata-mumbai-0-to-3-yrs-jobid-2JKCj8zisbtzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=1" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar70262323" onclick="syncShortlist('70262323'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">New Global Technologies</span> -->
# <span><img alt="New Global Technologies" src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/b-e-b-tech-diploma-engineers-new-global-technologies-bengaluru-bangalore-chennai-hyderabad-secunderabad-kolkata-mumbai-0-to-3-yrs-jobid-2JKCj8zisbtzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=1" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">B.E  , B.tech  , Diploma- engineers</a></h3>
# <h4><span class="srp-comp-name">New Global Technologies</span> | <span class="posting-time">1 days ago</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <a class="srphglt" href="https://m.timesjobs.com/jobskill/industrial-jobs" title="Industrial Jobs">Industrial</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/manufacturing-jobs" title="Manufacturing Jobs">Manufacturing</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/civil-jobs" title="Civil Jobs">Civil</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/software-testing-jobs" title="Software Testing Jobs">Software Testing</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/mechanical-metallurgy-jobs" title="Mechanical Metallurgy Jobs">Mechanical Metallurgy</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/design-jobs" title="Design Jobs">Design</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/electrical-design-jobs" title="Electrical Design Jobs">Electrical Design</a>
# </div>
# <div class="clearfix exp-loc">
# <div class="srp-loc">Bengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Kolkata,  Mumbai</div>
# <div class="srp-exp">0 - 3  Years</div>
# <div class="srp-sal">3.00 - 8.00 Lakhs</div>
# </div>
# </div>
# <!-- <div class="srp-action">
#
#
#
#   			<a id="apply70262323" href="#" class="srp-apply" onclick="syncApply('70262323'); return false;">Apply</a>
#
#
# 	<a id="shortlist70262323" href="#" class="srp-shortlist" onclick="syncShortlist('70262323'); return false;">Shortlist</a>
#   </div> -->
# </div>
# </li><li>
# <div class="srp-listing clearfix" id="liDiv71355625">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/receptionist-telecaller-tele-caller-data-entry-operator-true-faith-partners-delhi-1-to-3-yrs-jobid-eSi7hAyPSWlzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=2" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar71355625" onclick="syncShortlist('71355625'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">TRUE FAITH PARTNERS</span> -->
# <span><img alt="TRUE FAITH PARTNERS" src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/receptionist-telecaller-tele-caller-data-entry-operator-true-faith-partners-delhi-1-to-3-yrs-jobid-eSi7hAyPSWlzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=2" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">Receptionist , Telecaller , Tele Caller , Data Entry Operator</a></h3>
# <h4><span class="srp-comp-name">TRUE FAITH PARTNERS</span> | <span class="posting-time">24h</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <a class="srphglt" href="https://m.timesjobs.com/jobskill/microsoft-excel-jobs" title="Microsoft Excel Jobs">Microsoft Excel</a> <span class="srphglt">English Communication</span> <a class="srphglt" href="https://m.timesjobs.com/jobskill/english-fluency-jobs" title="English Fluency Jobs">English Fluency</a>
# </div>
# <div class="clearfix exp-loc">
# <div class="srp-loc">Delhi</div>
# <div class="srp-exp">1 - 3  Years</div>
# <div class="srp-sal">2.00 - 3.00 Lakhs</div>
# </div>
# </div>
# <!-- <div class="srp-action">
#
#
#
#   			<a id="apply71355625" href="#" class="srp-apply" onclick="syncApply('71355625'); return false;">Apply</a>
#
#
# 	<a id="shortlist71355625" href="#" class="srp-shortlist" onclick="syncShortlist('71355625'); return false;">Shortlist</a>
#   </div> -->
# </div>
# </li><li>
# <div class="srp-listing clearfix" id="liDiv71354939">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/staff-accountant-computer-operator-data-entry-birendra-singh-malsom-bengaluru-bangalore-chennai-gurgaon-hyderabad-secunderabad-kolkata-20-to-25-yrs-jobid-sG8__SLASH__o1j2WRZzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=3" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar71354939" onclick="syncShortlist('71354939'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">Birendra Singh Malsom</span> -->
# <span><img alt="Birendra Singh Malsom" src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/staff-accountant-computer-operator-data-entry-birendra-singh-malsom-bengaluru-bangalore-chennai-gurgaon-hyderabad-secunderabad-kolkata-20-to-25-yrs-jobid-sG8__SLASH__o1j2WRZzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=3" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">Staff Accountant , Computer Operator , Data Entry</a></h3>
# <h4><span class="srp-comp-name">Birendra Singh Malsom</span> | <span class="posting-time">2 days ago</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <a class="srphglt" href="https://m.timesjobs.com/jobskill/staff-accountant-jobs" title="Staff Accountant Jobs">Staff Accountant</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/bank-reconciliation-jobs" title="Bank Reconciliation Jobs">Bank Reconciliation</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/balance-sheet-jobs" title="Balance Sheet Jobs">Balance Sheet</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/reconciliation-jobs" title="Reconciliation Jobs">Reconciliation</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/staff-augmentation-jobs" title="Staff Augmentation Jobs">Staff Augmentation</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/vendor-management-jobs" title="Vendor Management Jobs">Vendor Management</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/system-administrator-jobs" title="system administrator Jobs">system administrator</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/customer-support-engineer-jobs" title="customer support engineer Jobs">customer support engineer</a>
# </div>
# <div class="clearfix exp-loc">
# <div class="srp-loc">Bengaluru / Bangalore,  Chennai,  Gurgaon,  Hyderabad/Secunderabad,  Kolkata</div>
# <div class="srp-exp">20 - 25  Years</div>
# <div class="srp-sal">30.00 - 60.00 Lakhs</div>
# </div>
# </div>
# <!-- <div class="srp-action">
#
#
#
#   			<a id="apply71354939" href="#" class="srp-apply" onclick="syncApply('71354939'); return false;">Apply</a>
#
#
# 	<a id="shortlist71354939" href="#" class="srp-shortlist" onclick="syncShortlist('71354939'); return false;">Shortlist</a>
#   </div> -->
# </div>
# </li><li>
# <div class="mobile-banner card-widget">
# <div class="ad" id="ad1">
# <div id="div-gpt-ad-1730193280415-0" style="min-width: 300px; min-height: 250px;">
# <script>
# 						googletag.cmd.push(function() { googletag.display('div-gpt-ad-1730193280415-0'); });
# 						</script>
# </div>
# </div>
# <div class="ad" id="ad2">
# <div id="gpt-passback" style="min-width: 300px; min-height: 250px;">
# <script>
# 						googletag.cmd.push(function() { googletag.display('gpt-passback'); });
# 						</script>
# </div>
# </div>
# </div>
# </li>
# <li>
# <div class="search-dream-job-container">
# <div class="search-dream-job-pos">
# <h4>Searching for your dream job?</h4>
# <div class="text">Let top companies find you. Sign up or log in to start applying today!</div>
# <a class="ui-btn" href="/mobile/registration.html?socRegFrom=TJMOB_SRP" style="margin-right: 4px;">Register</a>
# <a class="sign-btn ui-btn" href="/mobile/login.html">Login</a>
# </div>
# </div>
# </li>
# <li>
# <div class="srp-listing clearfix" id="liDiv71211727">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/data-entry-operator-office-assistant-marketing-assistant-risika-softech-solutions-bengaluru-bangalore-chennai-delhi-ncr-gurgaon-noida-greater-noida-0-to-1-yrs-jobid-Upt1qdIqXqlzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=4" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar71211727" onclick="syncShortlist('71211727'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">Risika Softech SolutionS</span> -->
# <span><img alt="Risika Softech SolutionS" src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/data-entry-operator-office-assistant-marketing-assistant-risika-softech-solutions-bengaluru-bangalore-chennai-delhi-ncr-gurgaon-noida-greater-noida-0-to-1-yrs-jobid-Upt1qdIqXqlzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=4" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">Data Entry Operator  /  Office Assistant  /  Marketing Assistant</a></h3>
# <h4><span class="srp-comp-name">Risika Softech SolutionS</span> | <span class="posting-time">2 days ago</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <a class="srphglt" href="https://m.timesjobs.com/jobskill/data-entry-jobs" title="data entry Jobs">data entry</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/microsoft-office-word-jobs" title="Microsoft Office Word Jobs">Microsoft Office Word</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/ms-office-jobs" title="Ms Office Jobs">Ms Office</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/typing-jobs" title="Typing Jobs">Typing</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/manager-jobs" title="manager Jobs">manager</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/team-leader-jobs" title="Team Leader Jobs">Team Leader</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/bpo-jobs" title="bpo Jobs">bpo</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/ites-jobs" title="ites Jobs">ites</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/content-writing-jobs" title="Content Writing Jobs">Content Writing</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/digital-marketing-jobs" title="digital marketing Jobs">digital marketing</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/part-time-jobs" title="part time Jobs">part time</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/teaching-jobs" title="Teaching Jobs">Teaching</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/tally-jobs" title="Tally Jobs">Tally</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/finance-jobs" title="Finance Jobs">Finance</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/accountant-jobs" title="Accountant Jobs">Accountant</a>
# </div>
# <div class="clearfix exp-loc">
# <div class="srp-loc">Bengaluru / Bangalore,  Chennai,  Delhi/NCR,  Gurgaon,  Noida/Greater Noida</div>
# <div class="srp-exp">0 - 1  Years</div>
# <div class="srp-sal">2.45 - 3.60 Lakhs</div>
# <div class="srp-vac">25</div>
# </div>
# <div class="wfh-icon">Work from home</div>
# </div>
# <!-- <div class="srp-action">
#
#
#
#   			<a id="apply71211727" href="#" class="srp-apply" onclick="syncApply('71211727'); return false;">Apply</a>
#
#
# 	<a id="shortlist71211727" href="#" class="srp-shortlist" onclick="syncShortlist('71211727'); return false;">Shortlist</a>
#   </div> -->
# </div>
# </li><li>
# <div class="srp-listing clearfix" id="liDiv71359173">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/direct-airport-data-entry-ground-staff-supervisor-incharge-aai-vijayawada-vadodara-mangalore-nagpur-bhubaneshwar-0-to-3-yrs-jobid-CFXQmFzT17NzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=5" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar71359173" onclick="syncShortlist('71359173'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">Akash A</span> -->
# <span><img alt="Akash A" src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/direct-airport-data-entry-ground-staff-supervisor-incharge-aai-vijayawada-vadodara-mangalore-nagpur-bhubaneshwar-0-to-3-yrs-jobid-CFXQmFzT17NzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=5" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">Direct Airport ,  Data Entry ,  Ground Staff ,  Supervisor ,  Incharge</a></h3>
# <h4><span class="srp-comp-name">Akash A</span> | <span class="posting-time">24h</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <a class="srphglt" href="https://m.timesjobs.com/jobskill/ground-handling-jobs" title="Ground Handling Jobs">Ground Handling</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/airport-operations-jobs" title="Airport Operations Jobs">Airport Operations</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/customer-service-jobs" title="Customer Service Jobs">Customer Service</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/system-administrator-jobs" title="system administrator Jobs">system administrator</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/cargo-supervisor-jobs" title="cargo supervisor Jobs">cargo supervisor</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/data-entry-jobs" title="data entry Jobs">data entry</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/computer-operator-jobs" title="computer operator Jobs">computer operator</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/engineer-jobs" title="engineer Jobs">engineer</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/technical-support-engineer-jobs" title="technical support engineer Jobs">technical support engineer</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/sales-jobs" title="sales Jobs">sales</a>
# </div>
# <div class="clearfix exp-loc">
# <div class="srp-loc">Vijayawada,  Vadodara,  Mangalore,  Nagpur,  Bhubaneshwar</div>
# <div class="srp-exp">0 - 3  Years</div>
# <div class="srp-sal">2.50 - 8.80 Lakhs</div>
# </div>
# </div>
# <!-- <div class="srp-action">
#
#
#
#   			<a id="apply71359173" href="#" class="srp-apply" onclick="syncApply('71359173'); return false;">Apply</a>
#
#
# 	<a id="shortlist71359173" href="#" class="srp-shortlist" onclick="syncShortlist('71359173'); return false;">Shortlist</a>
#   </div> -->
# </div>
# </li><li>
# <div class="srp-listing clearfix" id="liDiv71355002">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/sfmc-developer-ltimindtree-bengaluru-bangalore-3-to-5-yrs-jobid-9__PLUS__hz3K52AStzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=6" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar71355002" onclick="syncShortlist('71355002'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">LTIMindtree Ltd.</span> -->
# <span><img alt="LTIMindtree Ltd." src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/sfmc-developer-ltimindtree-bengaluru-bangalore-3-to-5-yrs-jobid-9__PLUS__hz3K52AStzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=6" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">SFMC Developer</a></h3>
# <h4><span class="srp-comp-name">LTIMindtree Ltd.</span> | <span class="posting-time">2 days ago</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <span class="srphglt">Mandatory Skills :HTML / HTML5</span> <a class="srphglt" href="https://m.timesjobs.com/jobskill/javascript-jobs" title="JavaScript Jobs">JavaScript</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/salesforce-marketing-cloud-campaign-operations-jobs" title="Salesforce Marketing Cloud Campaign Operations Jobs">Salesforce Marketing Cloud Campaign Operations</a>
# </div>
# <div class="clearfix exp-loc">
# <div class="srp-loc">Bengaluru / Bangalore</div>
# <div class="srp-exp">3 - 5  Years</div>
# <div class="srp-sal">As per Industry Standards</div>
# </div>
# </div>
# <!-- <div class="srp-action">
#
#
#
#   			<a id="apply71355002" href="#" class="srp-apply" onclick="syncApply('71355002'); return false;">Apply</a>
#
#
# 	<a id="shortlist71355002" href="#" class="srp-shortlist" onclick="syncShortlist('71355002'); return false;">Shortlist</a>
#   </div> -->
# </div>
# </li><li>
# <div class="mobile-banner card-widget">
# <div id="div-gpt-ad-1730193110443-0" style="min-width: 300px; min-height: 250px;">
# <script>
# 				  googletag.cmd.push(function() { googletag.display('div-gpt-ad-1730193110443-0'); });
# 				</script>
# </div>
# </div>
# </li>
# <li>
# <div class="srp-listing clearfix" id="liDiv71354953">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/devops-engineer-talpro-india-private-limited-bengaluru-bangalore-3-to-8-yrs-jobid-0xKXfmeBEdJzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=7" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar71354953" onclick="syncShortlist('71354953'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">TALPRO INDIA PRIVATE LIMITED</span> -->
# <span><img alt="TALPRO INDIA PRIVATE LIMITED" src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/devops-engineer-talpro-india-private-limited-bengaluru-bangalore-3-to-8-yrs-jobid-0xKXfmeBEdJzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=7" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">DevOps Engineer</a></h3>
# <h4><span class="srp-comp-name">TALPRO INDIA PRIVATE LIMITED</span> | <span class="posting-time">2 days ago</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <a class="srphglt" href="https://m.timesjobs.com/jobskill/docker-jobs" title="Docker Jobs">Docker</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/kubernetes-version-1-28-jobs" title="Kubernetes Version 1 28 Jobs">Kubernetes ( Version 1.28 )</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/jenkins-jobs" title="Jenkins Jobs">Jenkins</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/aws-codepipeline-jobs" title="AWS CodePipeline Jobs">AWS CodePipeline</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/terraform-jobs" title="Terraform Jobs">Terraform</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/ansible-jobs" title="Ansible Jobs">Ansible</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/ansible-tower-jobs" title="Ansible Tower Jobs">Ansible Tower</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/python-jobs" title="Python Jobs">Python</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/shell-scripting-jobs" title="Shell Scripting Jobs">Shell Scripting</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/aws-cloud-infrastructure-management-jobs" title="AWS Cloud Infrastructure Management Jobs">AWS Cloud Infrastructure Management</a>
# </div>
# <div class="clearfix exp-loc">
# <div class="srp-loc">Bengaluru / Bangalore</div>
# <div class="srp-exp">3 - 8  Years</div>
# <div class="srp-sal">20.10 - 35.00 Lakhs</div>
# </div>
# </div>
# <!-- <div class="srp-action">
#
#
#
#   			<a id="apply71354953" href="#" class="srp-apply" onclick="syncApply('71354953'); return false;">Apply</a>
#
#
# 	<a id="shortlist71354953" href="#" class="srp-shortlist" onclick="syncShortlist('71354953'); return false;">Shortlist</a>
#   </div> -->
# </div>
# </li><li>
# <div class="srp-listing clearfix" id="liDiv71355665">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/drilling-engineer-meena-namdeo-kedari-ahmedabad-delhi-ncr-kolkata-delhi-anantapur-15-to-20-yrs-jobid-fL2NimizUt9zpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=8" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar71355665" onclick="syncShortlist('71355665'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">Meena Namdeo Kedari</span> -->
# <span><img alt="Meena Namdeo Kedari" src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/drilling-engineer-meena-namdeo-kedari-ahmedabad-delhi-ncr-kolkata-delhi-anantapur-15-to-20-yrs-jobid-fL2NimizUt9zpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=8" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">Drilling Engineer</a></h3>
# <h4><span class="srp-comp-name">Meena Namdeo Kedari</span> | <span class="posting-time">1 days ago</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <a class="srphglt" href="https://m.timesjobs.com/jobskill/cost-estimates-jobs" title="Cost Estimates Jobs">Cost Estimates</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/well-design-jobs" title="Well Design Jobs">Well Design</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/data-analysis-jobs" title="Data Analysis Jobs">Data Analysis</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/bha-jobs" title="BHA Jobs">BHA</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/technical-support-jobs" title="Technical Support Jobs">Technical Support</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/engineering-support-jobs" title="Engineering Support Jobs">Engineering Support</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/well-control-jobs" title="Well Control Jobs">Well Control</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/risk-assessments-jobs" title="Risk Assessments Jobs">Risk Assessments</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/bp-jobs" title="BP Jobs">BP</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/wellview-jobs" title="Wellview Jobs">Wellview</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/cost-control-jobs" title="Cost Control Jobs">Cost Control</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/drill-string-jobs" title="Drill String Jobs">Drill String</a>
# </div>
# <div class="clearfix exp-loc">
# <div class="srp-loc">Ahmedabad,  Delhi/NCR,  Kolkata,  Delhi,  Anantapur</div>
# <div class="srp-exp">15 - 20  Years</div>
# <div class="srp-sal">30.40 - 50.60 Lakhs</div>
# </div>
# </div>
# <!-- <div class="srp-action">
#
#
#
#   			<a id="apply71355665" href="#" class="srp-apply" onclick="syncApply('71355665'); return false;">Apply</a>
#
#
# 	<a id="shortlist71355665" href="#" class="srp-shortlist" onclick="syncShortlist('71355665'); return false;">Shortlist</a>
#   </div> -->
# </div>
# </li><li>
# <div class="srp-listing clearfix" id="liDiv71359175">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/operations-analyst-machendra-reang-ghaziabad-gorakhpur-kanpur-lucknow-mathura-23-to-28-yrs-jobid-v0xi9uPmDaFzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=9" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar71359175" onclick="syncShortlist('71359175'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">Machendra Reang</span> -->
# <span><img alt="Machendra Reang" src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/operations-analyst-machendra-reang-ghaziabad-gorakhpur-kanpur-lucknow-mathura-23-to-28-yrs-jobid-v0xi9uPmDaFzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=9" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">Operations analyst</a></h3>
# <h4><span class="srp-comp-name">Machendra Reang</span> | <span class="posting-time">24h</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <span class="srphglt">Analytical Skills</span> <span class="srphglt">Problem-Solving Skills</span> <span class="srphglt">Data Analysis Skills</span> <span class="srphglt">Communication Skills</span>
# </div>
# <div class="clearfix exp-loc">
# <div class="srp-loc">Ghaziabad,  Gorakhpur,  Kanpur,  Lucknow,  Mathura</div>
# <div class="srp-exp">23 - 28  Years</div>
# <div class="srp-sal">25.00 - 40.00 Lakhs</div>
# </div>
# </div>
# <!-- <div class="srp-action">
#
#
#
#   			<a id="apply71359175" href="#" class="srp-apply" onclick="syncApply('71359175'); return false;">Apply</a>
#
#
# 	<a id="shortlist71359175" href="#" class="srp-shortlist" onclick="syncShortlist('71359175'); return false;">Shortlist</a>
#   </div> -->
# </div>
# </li><li>
# <div class="srp-listing clearfix" id="liDiv71357761">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/administrative-officer-meena-namdeo-kedari-surendranagar-valsad-vapi-fatehabad-hissar-jind-15-to-20-yrs-jobid-iRB4Mk8LxK5zpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=10" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar71357761" onclick="syncShortlist('71357761'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">Meena Namdeo Kedari</span> -->
# <span><img alt="Meena Namdeo Kedari" src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/administrative-officer-meena-namdeo-kedari-surendranagar-valsad-vapi-fatehabad-hissar-jind-15-to-20-yrs-jobid-iRB4Mk8LxK5zpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=10" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">Administrative Officer</a></h3>
# <h4><span class="srp-comp-name">Meena Namdeo Kedari</span> | <span class="posting-time">24h</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <a class="srphglt" href="https://m.timesjobs.com/jobskill/customer-service-jobs" title="Customer Service Jobs">Customer Service</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/data-entry-jobs" title="Data Entry Jobs">Data Entry</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/powerpoint-jobs" title="PowerPoint Jobs">PowerPoint</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/travel-arrangements-jobs" title="Travel Arrangements Jobs">Travel Arrangements</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/database-management-jobs" title="Database Management Jobs">Database Management</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/word-processing-jobs" title="Word Processing Jobs">Word Processing</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/office-equipment-jobs" title="Office Equipment Jobs">Office Equipment</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/provides-administrative-support-jobs" title="Provides Administrative Support Jobs">Provides Administrative Support</a>
# </div>
# <div class="clearfix exp-loc">
# <div class="srp-loc">Surendranagar,  Valsad -Vapi,  Fatehabad,  Hissar,  Jind</div>
# <div class="srp-exp">15 - 20  Years</div>
# <div class="srp-sal">40.50 - 55.60 Lakhs</div>
# </div>
# </div>
# <!-- <div class="srp-action">
#
#
#
#   			<a id="apply71357761" href="#" class="srp-apply" onclick="syncApply('71357761'); return false;">Apply</a>
#
#
# 	<a id="shortlist71357761" href="#" class="srp-shortlist" onclick="syncShortlist('71357761'); return false;">Shortlist</a>
#   </div> -->
# </div>
# </li><li>
# <div class="srp-listing clearfix" id="liDiv71304802">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/medical-biller-work-pro-mumbai-pune-nagpur-1-to-5-yrs-jobid-G__PLUS__vDqCg__SLASH__4CpzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=11" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar71304802" onclick="syncShortlist('71304802'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">Work Pro</span> -->
# <span><img alt="Work Pro" src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/medical-biller-work-pro-mumbai-pune-nagpur-1-to-5-yrs-jobid-G__PLUS__vDqCg__SLASH__4CpzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=11" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">Medical Biller</a></h3>
# <h4><span class="srp-comp-name">Work Pro</span> | <span class="posting-time">24h</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <a class="srphglt" href="https://m.timesjobs.com/jobskill/medical-billing-jobs" title="Medical Billing Jobs">Medical Billing</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/medical-termology-jobs" title="medical termology Jobs">"medical termology"</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/denial-jobs" title="Denial Jobs">Denial</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/icd-10-jobs" title="ICD 10 Jobs">"ICD 10"</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/medical-coder-jobs" title="Medical Coder Jobs">Medical Coder</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/clinical-data-management-jobs" title="Clinical Data Management Jobs">Clinical Data Management</a>
# </div>
# <div class="clearfix exp-loc">
# <div class="srp-loc">Mumbai,  Pune,  Nagpur</div>
# <div class="srp-exp">1 - 5  Years</div>
# <div class="srp-sal">1.00 - 5.00 Lakhs</div>
# </div>
# </div>
# <!-- <div class="srp-action">
#
#
#
#   			<a id="apply71304802" href="#" class="srp-apply" onclick="syncApply('71304802'); return false;">Apply</a>
#
#
# 	<a id="shortlist71304802" href="#" class="srp-shortlist" onclick="syncShortlist('71304802'); return false;">Shortlist</a>
#   </div> -->
# </div>
# </li><li>
# <div class="srp-listing clearfix" id="liDiv71357765">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/admissions-counselor-meena-namdeo-kedari-morbi-nadiad-navsari-palanpur-patan-10-to-15-yrs-jobid-txH2Mog4SLdzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=12" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar71357765" onclick="syncShortlist('71357765'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">Meena Namdeo Kedari</span> -->
# <span><img alt="Meena Namdeo Kedari" src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/admissions-counselor-meena-namdeo-kedari-morbi-nadiad-navsari-palanpur-patan-10-to-15-yrs-jobid-txH2Mog4SLdzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=12" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">Admissions Counselor</a></h3>
# <h4><span class="srp-comp-name">Meena Namdeo Kedari</span> | <span class="posting-time">24h</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <a class="srphglt" href="https://m.timesjobs.com/jobskill/crm-jobs" title="CRM Jobs">CRM</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/recruitment-strategies-jobs" title="Recruitment Strategies Jobs">Recruitment Strategies</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/recruitment-events-jobs" title="Recruitment Events Jobs">Recruitment Events</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/academic-programs-jobs" title="Academic Programs Jobs">Academic Programs</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/admission-decisions-jobs" title="Admission Decisions Jobs">Admission Decisions</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/admission-applications-jobs" title="Admission Applications Jobs">Admission Applications</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/graduate-programs-jobs" title="Graduate Programs Jobs">Graduate Programs</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/financial-aid-jobs" title="Financial Aid Jobs">Financial Aid</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/admissions-data-jobs" title="Admissions Data Jobs">Admissions Data</a>
# </div>
# <div class="clearfix exp-loc">
# <div class="srp-loc">Morbi,  Nadiad,  Navsari,  Palanpur,  Patan</div>
# <div class="srp-exp">10 - 15  Years</div>
# <div class="srp-sal">40.45 - 50.55 Lakhs</div>
# </div>
# </div>
# <!-- <div class="srp-action">
#
#
#
#   			<a id="apply71357765" href="#" class="srp-apply" onclick="syncApply('71357765'); return false;">Apply</a>
#
#
# 	<a id="shortlist71357765" href="#" class="srp-shortlist" onclick="syncShortlist('71357765'); return false;">Shortlist</a>
#   </div> -->
# </div>
# </li><li>
# <div class="mobile-banner card-widget">
# <div id="div-gpt-ad-1730193223085-0" style="min-width: 300px; min-height: 250px;">
# <script>
# 				  googletag.cmd.push(function() { googletag.display('div-gpt-ad-1730193223085-0'); });
# 				</script>
# </div>
# </div>
# </li>
# <li>
# <div class="srp-listing clearfix" id="liDiv71357508">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/administrative-assistant-meena-namdeo-kedari-anand-bhavnagar-gir-gondal-jetpur-10-to-15-yrs-jobid-hfVi0g__SLASH__Ex6xzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=13" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar71357508" onclick="syncShortlist('71357508'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">Meena Namdeo Kedari</span> -->
# <span><img alt="Meena Namdeo Kedari" src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/administrative-assistant-meena-namdeo-kedari-anand-bhavnagar-gir-gondal-jetpur-10-to-15-yrs-jobid-hfVi0g__SLASH__Ex6xzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=13" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">Administrative Assistant</a></h3>
# <h4><span class="srp-comp-name">Meena Namdeo Kedari</span> | <span class="posting-time">1 days ago</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <a class="srphglt" href="https://m.timesjobs.com/jobskill/customer-service-jobs" title="Customer Service Jobs">Customer Service</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/data-entry-jobs" title="Data Entry Jobs">Data Entry</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/powerpoint-jobs" title="PowerPoint Jobs">PowerPoint</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/travel-arrangements-jobs" title="Travel Arrangements Jobs">Travel Arrangements</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/database-management-jobs" title="Database Management Jobs">Database Management</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/word-processing-jobs" title="Word Processing Jobs">Word Processing</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/office-equipment-jobs" title="Office Equipment Jobs">Office Equipment</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/provides-administrative-support-jobs" title="Provides Administrative Support Jobs">Provides Administrative Support</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/purchase-orders-jobs" title="Purchase Orders Jobs">Purchase Orders</a>
# </div>
# <div class="clearfix exp-loc">
# <div class="srp-loc">Anand,  Bhavnagar,  Gir,  Gondal,  Jetpur</div>
# <div class="srp-exp">10 - 15  Years</div>
# <div class="srp-sal">40.45 - 50.55 Lakhs</div>
# </div>
# </div>
# <!-- <div class="srp-action">
#
#
#
#   			<a id="apply71357508" href="#" class="srp-apply" onclick="syncApply('71357508'); return false;">Apply</a>
#
#
# 	<a id="shortlist71357508" href="#" class="srp-shortlist" onclick="syncShortlist('71357508'); return false;">Shortlist</a>
#   </div> -->
# </div>
# </li><li>
# <div class="srp-listing clearfix" id="liDiv71357504">
# <a class="srp-apply-new" href="https://m.timesjobs.com/mobile/job-detail/actuary-meena-namdeo-kedari-kolkata-mumbai-dadra-nagar-haveli-silvassa-pondicherry-puducherry-kakinada-10-to-15-yrs-jobid-AvU1qLVLTGRzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=14" onclick="trackClickEvent('Search Result Page','SRPJobDetail');"></a>
# <span class="short-star" id="shortstar71357504" onclick="syncShortlist('71357504'); return false;"></span>
# <div class="srp-job-bx">
# <div class="clearfix srp-heading">
# <div class="srp-comp-logo">
# <!-- <span class="logo-comp-name">Meena Namdeo Kedari</span> -->
# <span><img alt="Meena Namdeo Kedari" src="/resources/images/svg_images/comp-default-logo.svg"/></span>
# </div>
# <div class="srp-job-heading">
# <h3><a href="https://m.timesjobs.com/mobile/job-detail/actuary-meena-namdeo-kedari-kolkata-mumbai-dadra-nagar-haveli-silvassa-pondicherry-puducherry-kakinada-10-to-15-yrs-jobid-AvU1qLVLTGRzpSvf__PLUS__uAgZw==&amp;bc=+&amp;sequence=14" onclick="trackClickEvent('Search Result Page','SRPJobDetail');">Actuary</a></h3>
# <h4><span class="srp-comp-name">Meena Namdeo Kedari</span> | <span class="posting-time">1 days ago</span></h4>
# </div>
# </div>
# <div class="srp-keyskills">
# <a class="srphglt" href="https://m.timesjobs.com/jobskill/risk-management-jobs" title="Risk Management Jobs">Risk Management</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/vba-jobs" title="VBA Jobs">VBA</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/gaap-jobs" title="GAAP Jobs">GAAP</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/sas-jobs" title="SAS Jobs">SAS</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/health-insurance-jobs" title="Health Insurance Jobs">Health Insurance</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/financial-reports-jobs" title="Financial Reports Jobs">Financial Reports</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/term-care-jobs" title="Term Care Jobs">Term Care</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/product-development-jobs" title="Product Development Jobs">Product Development</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/projection-jobs" title="Projection Jobs">Projection</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/portfolio-jobs" title="Portfolio Jobs">Portfolio</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/liability-management-jobs" title="Liability Management Jobs">Liability Management</a> <a class="srphglt" href="https://m.timesjobs.com/jobskill/data-analysis-jobs" title="Data Analysis Jobs">Data Analysis</a>
# </div>
# <div class="clearfix exp-loc">
# ...
#
#
# });
# jQuery(window).load(function(){
#
# });
# </script>
# <script>
#   $( ".search-result .srp-listing" ).on( "swipeleft", swipeleftHandler );
#   function swipeleftHandler( event ){
#     $(this).addClass( "srp-swipeleft" );
# 	$(this).parent().siblings().find('.srp-listing').removeClass( "srp-swipeleft" );
#   }
#   $( ".search-result .srp-listing" ).on( "swiperight", swiperightHandler );
#   function swiperightHandler( event ){
#     $(this).removeClass( "srp-swipeleft" );
#   }
#   jQuery(document).on('click', '.srp-filter', function (){
#   	if(totalJobsCount!=0){
# 		jQuery('body').addClass('filter-active');
# 		trackClickEvent('Search Result Page','Filter/Sort');
# 	}
# });
# jQuery(document).on('click', '.filter-back', function (){
# 	jQuery('body').removeClass('filter-active');
# });
# $(document).ready(function() {
# 	$('div:has(div.wfh-icon)').addClass('wfh-height');
# 	$('div:has(div.srp-walkin)').addClass('walkin-height');
# });
# </script>
# <script type="text/javascript">
# (window.CE_API || (window.CE_API=[])).push(function(){
#         setTimeout(function() {
#                 CE2.showSurvey("97ee8c1a-4607-4a1f-876c-8452b05a96e0");
#                 console.log('...CE2.showSurvey...')
#                 }, 30000);
# });
# </script>
# <script>
# 	jQuery('.sort-box').click(function(){
# 		jQuery('.sort-sheet').addClass('show-modal').enhanceWithin();
# 		jQuery('body').css('overflow', 'hidden');
# 	});
# 	jQuery('.close, .backdrop').click(function(){
# 		jQuery('.sort-sheet').removeClass('show-modal');
# 		jQuery('body').css('overflow', '');
# 	});
# 	jQuery('.filter-box').click(function(){
# 		jQuery('.filter-sheet').addClass('show-modal').enhanceWithin();
# 		jQuery('body').css('overflow', 'hidden');
# 	});
# 	jQuery('.close, .backdrop').click(function(){
# 		jQuery('.filter-sheet').removeClass('show-modal');
# 		jQuery('body').css('overflow', '');
# 	});
#   </script>
# <script>
#
# 	function __dynCountElement(obj){
# 		var _gWidth = 0;
# 		var pwidth = $(obj).outerWidth() - 100;
# 		var _lcount = 0;
# 		console.log(pwidth,obj)
#
# 		function GetWidths(id) {
# 			var i = 0;
# 			var isShow = 0;
# 			$(id).each(function (index) {
# 				i += parseInt($(this).outerWidth(true));
# 				if(pwidth < i){
# 					if(isShow == 0){
# 						_lcount = index;
# 					}
# 					isShow = 1;
# 					$(this).addClass("nodisplay");
# 				}
# 			});
# 			return isShow;
# 		}
#
# 		var totalWidthCount2 = GetWidths(obj.find("a, span"));
# 		if(totalWidthCount2 == 1){
# 			var _len = $(obj.find("a, span")).length;
# 			var _rcount = _len - _lcount;
# 			// append the lable code;
# 			$(obj).append("<span class='srp-tag'> +"+ _rcount +" more</span>");
# 		}
# 	}
#
# 	$(function(){
# 		$('.srp-keyskills').each(function(){
# 			__dynCountElement($(this));
# 		})
# 	})
# 	</script>
# <script>
# 		$(document).ready(function() {
# 			// Function to display one ad
# 			function showAd(adId) {
# 				// Hide both ads
# 				$('#ad1').hide();
# 				$('#ad2').hide();
#
# 				// Show the selected ad
# 				$('#' + adId).show();
# 			}
#
# 			// Function to start the random ad display
# 			function startRandomAds() {
# 				// Randomly choose which ad to show first
# 				const ads = ['ad1', 'ad2'];
# 				let firstAd = ads[Math.floor(Math.random() * ads.length)];
#
# 				// Display the first ad immediately
# 				showAd(firstAd);
#
# 				// After 4 seconds, display the second ad
# 				setTimeout(function() {
# 					// Randomly select the second ad (different from the first)
# 					const secondAd = firstAd === 'ad1' ? 'ad2' : 'ad1';
# 					showAd(secondAd);
#
# 					// Now, start alternating ads every 4 seconds
# 					setInterval(function() {
# 						// Randomly switch between the two ads every 4 seconds
# 						const nextAd = firstAd === 'ad1' ? 'ad2' : 'ad1';
# 						showAd(nextAd);
# 						// Update the firstAd for the next interval
# 						firstAd = nextAd;
# 					}, 6000); // 4 seconds interval
#
# 				}, 6000); // Wait for 4 seconds before showing the second ad
# 			}
#
# 			// Start the random ad switching when the page loads
# 			startRandomAds();
# 		});
# 	</script>
# <script type="text/javascript">
#
#
# 	function trackClickEvent(category,action){
# 		//_gaq.push(['_trackEvent', category, action]);
# 		console.log("category ===== " + category +  "  |  action ===== " + action);
# 	}
#
#
#
# </script>
# <!-- <script src="http://tags.crwdcntrl.net/c/2890/cc_af.js"></script> -->
# <style>
# .registration-overlay{background-color: #333;opacity: 0.8;position: fixed;left: 0px;bottom: 0px;top: 0px;z-index: 999999;height: 100%;width: 100%;overflow: hidden;background-position: center;background-repeat: no-repeat;display: none;}
# .registration-message {background: #fff;position: fixed;left: 10px;top: 0px;right: 10px;bottom: 0px;z-index: 9999999;overflow: hidden;background-position: center;background-repeat: no-repeat; height: 310px;border-radius: 8px;margin: auto;font-size: 14px;padding: 20px;display: none;}
# .registration-message p {margin: 0px;padding: 0 30px 0px 30px;text-align: center;line-height: 21px;font-size: 14px;}
# .registration-message .registration-close {color: #ccc;font-size: 16px;font-weight: bold;top: 10px;right: 15px;position: absolute;cursor: pointer;}
# .registration-message .registration-btn-close {text-decoration: none;color: #fff;font-size: 12px;background-color: #EE2525;	text-align: center;	-webkit-transition: .2s ease-out;transition: .2s ease-out;cursor: pointer;padding: 10px 20px;font-weight: bold;border:none;}
# .registration-message .heading {color: #01439F;	font-size: 18px;font-weight: bold;text-align: center;padding: 24px 0;margin: 0px;}
# </style>
# <div class="registration-overlay"></div>
# <div class="registration-message">
# <span class="registration-close">X</span>
# <h2 class="heading">We care for you!</h2>
# <p>
# <strong>Please note:</strong> TimesJobs or its recruiting partners do
# 		not charge money or fee from candidates for recruitment or anything
# 		else. If anyone calls you asking for money or payment for
# 		registration, application process, resume service, etc, then please
# 		report it immediately to <a href="mailto:corporatecare@timesjobs.com">corporatecare@timesjobs.com</a>
# <br/>
# <br/>
# <button class="registration-btn-close">OK</button>
# </p>
# </div>
# <script>
# 	let isFDivClosed = true;
# 	$(document).ready(function(){
# 		getFraudBannerStatus();
# 	});
#
# 	/*
# 	$(window).on('load', function(){
# 		$(".registration-overlay, .registration-message").css("display", "block");
# 	});
# 	*/
# 	$( ".registration-close, .registration-btn-close" ).on( "click", function() {
# 		updateStatus();
# 	});
#
# 	function updateStatus(){
# 		if(isFDivClosed === false){
# 			updateFraudBannerStatus();
# 		}
#
# 	}
#
# 	setTimeout(autoFDivClose, 30000);
#
# 	function autoFDivClose(){
# 		if(isFDivClosed === false){
# 			//updateFraudBannerStatus();
# 			$(".registration-overlay, .registration-message").css("display", "none");
# 			isFDivClosed = true;
# 		}
# 	}
#
# 	function updateFraudBannerStatus() {
# 		ajaxController.updateFraudBannerStatus({callback : updateFraudBannerStatusSuccess, errorHandler : updateFraudBannerStatusError});
# 	}
#
# 	function getFraudBannerStatus(){
# 		ajaxController.getFraudBannerStatus({callback : getFraudBannerStatusSuccess, errorHandler : getFraudBannerStatusError});
# 	}
#
# 	function updateFraudBannerStatusSuccess(data){
# 		console.log('updateFraudBannerStatusSuccess : ',data)
# 		$(".registration-overlay, .registration-message").css("display", "none");
# 		isFDivClosed = true;
# 	}
#
# 	function updateFraudBannerStatusError(data){
# 		console.log('updateFraudBannerStatusError')
# 	}
#
# 	function getFraudBannerStatusSuccess(data){
# 		console.log(' getFraudBannerStatusSuccess : ',data)
# 		if(typeof data === 'string'){
# 			data = JSON.parse(data);
# 		}
# 		if(data != null && data['showfraudbanner'] !=null && data['showfraudbanner']===true){
# 			$(".registration-overlay, .registration-message").css("display", "block");
# 			isFDivClosed=false;
# 		}
# 	}
#
# 	function getFraudBannerStatusError(data){
#
# 	}
# </script>
# <!--
# -->
# <!--
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	<div class="gdpr-info" id="gdprInfo">
# 		<div class="row clearfix">
# 			<div class="col s11">
# 		This site uses cookies so that we can remember you and understand
# 		how you interact with our website. This allows us to improve and
# 		customize your browsing experience. To find out more about the
# 		cookies we use, see our
# 			<a target="_blank" href="https://www.timesjobs.com//candidate/privacyPolicy.html">Cookies Policy</a>.
# 				</div>
# 			<div class="col s1">
# 		<button class="gdpr-btn btn">OK</button>
# 				</div>
# 			</div>
# 	</div>
# 	<script>
# 		jQuery(document).ready(function() {
# 			jQuery(".gdpr-btn").click(function(){
# 				jQuery.ajax({
# 		            async:false,
# 		            url:'/mobile/ajax/gdpr-compliance.html',
# 		            cache:false,
# 		            data:{
# 		            	act:'OK',
# 		            	src:'TJMOB'
# 					},
# 		            beforeSend:function(){
# 						console.info("GDPR compliance ok");
# 					},
# 					success:function(htmlResponse){
# 						jQuery(".gdpr-info").remove();
# 					}
# 				});
# 			});
# 		});
# 	</script>
#
#
#
#
# <script>
# const bannerContainer = document.getElementById('gdprInfo');
# function showBannerByCountry(ip_address) {
#     if (ip_address === 'IN') {
#         bannerContainer.style.display = 'none';
#     }
# 	else{
# 		 bannerContainer.style.display = 'block';
# 	}
# }
#
#
# /* fetch('https://api.techgig.com/api/v1/techgig/tguser/loadCountryByIP?ip_address=11.22.33.44')
#     .then(response => response.json())
#     .then(data => {
#         const ip_address = data.country;
# 		alert(ip_address);
#         showBannerByCountry(ip_address);
#     })
#     .catch(error => {
#         console.error('Error fetching geolocation:', error);
#     });
#     */
#
#     /*$.post('https://api.techgig.com/api/v1/techgig/tguser/loadCountryByIP?ip_address=11.22.33.44', function(data, status){
#     	console.log("Response: " + JSON.stringify(data));
#     	if(data.status == true && data.status == 200 && data.message =='success'){
#     		let result = data.result;
#     		showBannerByCountry(result.countryCode);
#     	}
#   	});*/
#
#    $.post('https://api.techgig.com/api/v1/techgig/tguser/loadCountryByIP?ip_address=202.59.15.178', function(data, status){
#         console.log("Response: " + JSON.stringify(data));
#         if(data.status == true && data.status_code == 200 && data.message =='success'){
#             let result = data.result;
#             showBannerByCountry(result.countryCode);
#         }
#       });
# </script> -->
# <!--
# <script src="https://static.clmbtech.com/ase/2320/825/aa.js" type="text/javascript"></script>
# <script>
# 	var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "6036484" });
#     (function() {
#     	var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#         s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#         el.parentNode.insertBefore(s, el);
# 	})();
# </script> -->
# <!-- <script type="text/javascript" src="//script.crazyegg.com/pages/scripts/0066/1644.js" async="async"></script> -->
# <script type="text/javascript">
#     (function(c,l,a,r,i,t,y){
#         c[a]=c[a]||function(){(c[a].q=c[a].q||[]).push(arguments)};
#         t=l.createElement(r);t.async=1;t.src="https://www.clarity.ms/tag/"+i;
#         y=l.getElementsByTagName(r)[0];y.parentNode.insertBefore(t,y);
#     })(window, document, "clarity", "script", "oj0fpk86cw");
# </script>
# <!-- Google GA4 Code start here -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-LNR0M7BMEN"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-LNR0M7BMEN');
# </script>
# <!-- Google GA4 Code close here -->
# <!-- Facebook Pixel Code -->
# <!--<script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '1263998740408550');
#   fbq('track', 'PageView');
#
#
# </script>
# <noscript><img height="1" width="1" alt="" style="display:none" alt="" src="https://www.facebook.com/tr?id=1263998740408550&ev=PageView&noscript=1"
# /></noscript> -->
# <!-- End Facebook Pixel Code -->
# <script>
# 	if(window.nv){
#     	nv('user', '', {});
# 	}
# </script>
# <script>
# 	$(document).ready(function(){
#         $(window).scroll(function(){
#             if ($(this).scrollTop() > 70) {
#                 $('#widgetshowbtn').css("width", "180px");
# 				$('#widgetshowbtn span').css("display","inline-block");
#             } else {
#                 $('#widgetshowbtn').css("width", "48px")
# 				$('#widgetshowbtn span').css("display","none");
#            }
#         });
#     });
# </script>
# <!-- google one tap -- start -->
# <script async="" defer="" src="https://accounts.google.com/gsi/client"></script>
# <script type="text/javascript">
# 		function handleCredentialResponse(response) {
# 		  // Here we can do whatever process with the response we want
# 		  // Note that response.credential is a JWT ID token
# 		  console.log("Encoded JWT ID token: " + response.credential);
# 		  console.log('All : ',response)
# 		  googleOneTapLogin(response.credential);
# 		}
# 		window.onload = function () {
# 		  google.accounts.id.initialize({
# 		    client_id: "819793255355-3574gl7e6o6pkq7cc46dedolg7hae69k.apps.googleusercontent.com", // Replace with your Google Client ID
# 		    callback: handleCredentialResponse, // We choose to handle the callback in client side, so we include a reference to a function that will handle the response
# 		    //login_uri: "http://localhost:8080/gots/callback"
# 		    //ux_mode: "redirect",
# 		    //auto_select="false"
# 		    cancel_on_tap_outside: false
# 		  });
#
# 		  // You can skip the next instruction if you don't want to show the "Sign-in" button
# 		  /* google.accounts.id.renderButton(
# 	      	document.getElementById("g_id_signin"),
# 	      	{ theme: "outline", size: "large" }  // customization attributes
# 	        ); */
#
# 		  google.accounts.id.prompt((notification) =>{
# 		  	if(notification.isDisplayMoment()){
# 		  		let moment_ = notification.getMomentType();
# 		  		console.log(" .......... Google One Tap Moment : "+moment_);
# 		  	}
# 		  	if(notification.isDisplayed()){
# 		  		console.log(" .......... Google One Tap Displayed");
# 		  		$('#modalwrap').show();
# 		  	}
# 		  	if(notification.isNotDisplayed()){
# 		  		let notDisplayReason = notification.getNotDisplayedReason();
# 		  		console.log(" .......... Google One Tap Not Displayed Reason : "+notDisplayReason)
# 		  	}
# 		  	if(notification.isSkippedMoment()){
# 		  		let skip_reason = notification.getSkippedReason();
# 		  		console.log(" .......... Google One Tap Dismissed : "+skip_reason)
# 		  		$('#modalwrap').hide();
# 		  	}
# 		  	if(notification.isDismissedMoment()){
# 		  		let dismissReason = notification.getDismissedReason();
# 		  		console.log(" .......... Google One Tap Dismissed : "+dismissReason)
# 		  		$('#modalwrap').hide();
# 		  	}
#
# 		  }); // Display the One Tap dialog
#
# 		}
# 		function googleOneTapLogin(jwt){
# 			console.log(" jwt : ",jwt);
# 			ajaxController.googleOneTapLogin(jwt, encodeURIComponent(window.location.href), "TJWEB", {callback : googleOneTapLoginSuccess,errorHandler : googleOneTapLoginError});
# 		}
# 		function googleOneTapLoginSuccess(data){
# 			console.log(' googleOneTapLoginSuccess ',data)
# 			data = JSON.parse(data)
# 			if(data != null && data["rurl"] != null){
# 				window.location.href = data["rurl"];
#    	 		}
# 		}
# 		function googleOneTapLoginError(data){
# 			console.log(' googleOneTapLoginError ',data)
# 		}
#
# </script>
# <div class="modalwrap" id="modalwrap" style="display: none;">
# <div class="zindex loggedin_gmail">
# <div data-auto_prompt="false" data-client_id="819793255355-3574gl7e6o6pkq7cc46dedolg7hae69k.apps.googleusercontent.com" data-login_uri="https://social.timesjobs.com/harvest/callback.html?pId=ggl&amp;apc=tj" id="g_id_onload">
# </div>
# </div>
# </div>
# <!-- google one tap -- end -->
# <!-- User Not Logged In -->
# <!-- google one tap -- end -->
# </body>
# </html>
